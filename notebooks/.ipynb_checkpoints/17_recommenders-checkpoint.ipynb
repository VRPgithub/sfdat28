# %%
# """
# Class 15: Recommendation Engines
# Content based and Collaborative based filtering
# Jaccard Similarity
# Modified KNN Algorithm
# """

# %%
########################################
## Collaborative-Based User Filtering ##
########################################

# %%
import pandas as pd

# %%
#read in brands data
user_brands = pd.read_csv('../data/user_brand.csv')

# %%
#look at count of stores
user_brands.Store.value_counts()
#user_brands.head()
# Out:
# Target                        1866
# Old Navy                      1200
# Home Depot                    1186
# Kohl's                        1157
# Banana Republic                932
# Nordstrom                      904
# Gap                            860
# Crate & Barrel                 816
# Express                        785
# KitchenAid                     700
# J.Crew                         569
# Container Store                564
# Steve Madden                   539
# Guess                          509
# Cuisinart                      506
# Nine West                      489
# Calvin Klein                   476
# Levi's                         472
# Converse                       456
# New Balance                    438
# BCBGMAXAZRIA                   429
# Restoration Hardware           410
# Lacoste                        405
# Kenneth Cole                   366
# Kate Spade                     354
# Puma                           350
# Melissa & Doug                 335
# DKNY                           328
# Last Call by Neiman Marcus     308
# Crocs                          293
#                               ...
# UNIQLO                           1
# Janie and Jack                   1
# Billionaire Boys Club            1
# Discovery Channel Store          1
# Barneys                          1
# Keds                             1
# Black Diamond                    1
# Lord & Taylor                    1
# Boden                            1
# Vince Camuto                     1
# Crate and Barrel                 1
# Bloomingdale's                   1
# Amazon.com                       1
# Grand                            1
# ZOO                              1
# Joseph Abboud                    1
# Hugo Boss                        1
# Chanel                           1
# Sky                              1
# Gymboree                         1
# Marmot                           1
# Stride Rite                      1
# Oakley                           1
# DC                               1
# J Jill                           1
# Carter                           1
# Brooks Brothers                  1
# David Tutera                     1
# Barneys Warehouse                1
# Walk-Over                        1
# Name: Store, dtype: int64

# %%
# Series of user IDs, note the duplicates
user_ids = user_brands.ID

# %%
user_ids.head()
# Out:
# 0    80002
# 1    80002
# 2    80010
# 3    80010
# 4    80010
# Name: ID, dtype: int64

# %%
# EXERCISE 
# create a dictionary called brandsfor that takes in a user id and outputs a list of the brands they like
# brandsfor = ANSWER HEREEEEEE

# key == a user ID, and the value is a 
# value == list of stores that the user "likes"
# example brandsfor[83065] == ["Kohl's", 'Target']

brandsfor = dict(user_brands.groupby('ID').Store.apply(lambda x:list(x)))

brandsfor[81920]

# brandstmp = dict(user_brands.groupby('ID')['Store'].apply(list)) another way of doing the same
# Out:
# ["Levi's",
#  'Puma',
#  'KitchenAid',
#  'Cuisinart',
#  'Villeroy & Boch',
#  'Restoration Hardware',
#  '6pm.com',
#  'Target',
#  'Container Store',
#  'Home Depot',
#  'Shoebuy']

# %%
# ANSWER

brandsfor = dict(user_brands.groupby('ID').Store.apply(lambda x:list(x)))

# %%
brandsfor[83065]
# Out:
# ["Kohl's", 'Target']

# %%
# try it out. User 83065 likes Kohl's and Targe

# %%
# User 82983 likes many more!
brandsfor[82983]
# Out:
# ['Hanky Panky',
#  'Betsey Johnson',
#  'Converse',
#  'Steve Madden',
#  'Old Navy',
#  'Target',
#  'Nordstrom']

# %%
########################
## Jaccard Similarity ##
########################

# %%
#
#The Jaccard Similarity allows us to compare two sets
#If we regard people as merely being a set of brands they prefer
#the Jaccard Similarity allows us to compare people
#
#Example. the jaccard similarty between user 82983 and 83065 is .125
#            because
#             brandsfor['83065'] == ["Kohl's", 'Target']
#             brandsfor['82983'] == ['Hanky Panky', 'Betsey Johnson', 'Converse', 'Steve Madden', 'Old Navy', 'Target', 'Nordstrom']

# the intersection of these two sets is just set("Target")
# the union of the two sets is set(['Target', 'Hanky Panky', 'Betsey Johnson', 'Converse', 'Steve Madden', 'Old Navy', 'Target', 'Nordstrom'])
# so the len(intersection) / len(union) = 1 / 8 == .125

# EXERCISE: what is the Jaccard Similarity 
#           between user 82956 and user 82963?
#

# %%
# ANSWER HERE







# 0.3333333333333333

# %%
# '''
# EXERCISE: Complete the jaccard method below.
#           It should take in a list of brands, and output the 
#           jaccard similarity between them

# This should work with anything in the set, for example
# jaccard([1,2,3], [2,3,4,5,6])  == .3333333

# HINT: set1 & set2 is the intersection
#       set1 | set2 is the union

# '''

# %%
def jaccard(first, second):
  first = set(first)
  second = set(second)
  # the line below should be changed
  # ANSWER HEREEEEEE
  return (len(first & second)/(len(first | second) * 1.0))  


print jaccard(brandsfor[83065], brandsfor[82983])
# Out:
# 0.125

# %%
def jaccard(first, second):
  first = set(first)
  second = set(second)
  return len(first & second) / float(len(first | second))

# %%
# try it out!
brandsfor[83065] # brands for user 83065
brandsfor[82983] # brands for user 82983
jaccard(brandsfor[83065], brandsfor[82983])
jaccard(brandsfor[82956], brandsfor[82963])
# Out:
# 0.3333333333333333

# %%
#######################
### Our Recommender ###
#######################

# %%
# '''
# Our recommender will be a modified KNN collaborative algorithm.
# Input: A given user's brands that they like
# Output: A set (no repeats) of brand recommendations based on
#         similar users preferences

# 1. When a user's brands are given to us, we will calculate the input user's
# jaccard similarity with every person in our brandsfor dictionary

# 2. We will pick the K most similar users and recommend
# the brands that they like that the given user doesn't know about

# EXAMPLE:
# Given User likes ['Target', 'Old Navy', 'Banana Republic', 'H&M']
# Outputs: ['Forever 21', 'Gap', 'Steve Madden']
# '''

# %%
given_user = ['Target', 'Old Navy', 'Banana Republic', 'H&M']

# %%
#similarty between user 83065 and given user
brandsfor[83065]
jaccard(brandsfor[83065], given_user) 
# should be 0.2
# Out:
# 0.2

# %%
# '''
# EXERCISE
#     Find the similarty between given_user and ALL of our users
#     output should be a dictionary where
#     the key is a user id and the value is the jaccard similarity
# {...
#  {81920: 0.07142857142857142,
#  81921: 0.25,
#  90114: 0.18181818181818182,
#  81923: 0.25,
#  ...}
# '''

# %%
# ANSWER HEREEEEEE
similarities
# Out:
# {81920: 0.07142857142857142,
#  81921: 0.25,
#  90114: 0.18181818181818182,
#  81923: 0.25,
#  90118: 0.07142857142857142,
#  81927: 0.2857142857142857,
#  90121: 0.2222222222222222,
#  81932: 0.0,
#  81933: 0.15384615384615385,
#  90126: 0.0,
#  87999: 0.2,
#  90128: 0.2,
#  81937: 0.0,
#  81938: 0.08333333333333333,
#  81942: 0.16666666666666666,
#  90135: 0.0,
#  81944: 0.0,
#  81948: 0.0,
#  81949: 0.0,
#  81950: 0.13333333333333333,
#  81951: 0.125,
#  81952: 0.0,
#  81956: 0.0,
#  90149: 0.09523809523809523,
#  81958: 0.14285714285714285,
#  90152: 0.25,
#  81961: 0.0,
#  81962: 0.08333333333333333,
#  90155: 0.2,
#  81965: 0.0,
#  81966: 0.1,
#  81666: 0.0,
#  81972: 0.25,
#  90165: 0.0,
#  81976: 0.18181818181818182,
#  90169: 0.05555555555555555,
#  90170: 0.2222222222222222,
#  81982: 0.2857142857142857,
#  90175: 0.0,
#  81985: 0.07142857142857142,
#  90179: 0.5,
#  90180: 0.0,
#  81989: 0.2857142857142857,
#  90183: 0.0,
#  81992: 0.2,
#  90185: 0.15,
#  81994: 0.0,
#  81996: 0.05555555555555555,
#  90125: 0.3333333333333333,
#  82000: 0.14285714285714285,
#  90193: 0.4,
#  82003: 0.10344827586206896,
#  82004: 0.16666666666666666,
#  90197: 0.0,
#  82006: 0.25,
#  90199: 0.0,
#  82009: 0.18181818181818182,
#  90202: 0.16666666666666666,
#  90205: 0.0,
#  90207: 0.2857142857142857,
#  82018: 0.0,
#  80571: 0.0,
#  90213: 0.0,
#  90129: 0.0,
#  90217: 0.09375,
#  82027: 0.08333333333333333,
#  82029: 0.25,
#  90222: 0.0,
#  82031: 0.3333333333333333,
#  82032: 0.21428571428571427,
#  82033: 0.0,
#  82036: 0.07692307692307693,
#  90234: 0.16666666666666666,
#  82044: 0.42857142857142855,
#  90237: 0.13333333333333333,
#  90239: 0.14285714285714285,
#  82048: 0.25,
#  82049: 0.0,
#  82051: 0.125,
#  90246: 0.1111111111111111,
#  82056: 0.25,
#  90249: 0.11764705882352941,
#  90251: 0.25,
#  82063: 0.25,
#  82064: 0.3,
#  90136: 0.2727272727272727,
#  82066: 0.0,
#  82067: 0.0,
#  90263: 0.16666666666666666,
#  82072: 0.0,
#  82073: 0.08333333333333333,
#  82074: 0.2,
#  82077: 0.2857142857142857,
#  90271: 0.0,
#  90273: 0.043478260869565216,
#  90276: 0.0,
#  82086: 0.08333333333333333,
#  90280: 0.2,
#  82089: 0.09090909090909091,
#  90282: 0.0,
#  82091: 0.2,
#  82092: 0.1111111111111111,
#  82093: 0.0,
#  90287: 0.0,
#  87411: 0.0,
#  90293: 0.0,
#  82102: 0.16666666666666666,
#  90297: 0.125,
#  82109: 0.25,
#  90302: 0.0,
#  90303: 0.25,
#  82114: 0.25,
#  82115: 0.14285714285714285,
#  82116: 0.14285714285714285,
#  82117: 0.0,
#  82118: 0.25,
#  82119: 0.1111111111111111,
#  82120: 0.14285714285714285,
#  90313: 0.25,
#  90315: 0.07142857142857142,
#  90317: 0.42857142857142855,
#  88661: 0.0,
#  90319: 0.0,
#  82130: 0.0,
#  82131: 0.0,
#  82133: 0.0,
#  90326: 0.3,
#  90148: 0.23076923076923078,
#  90336: 0.0,
#  82145: 0.0,
#  90338: 0.0,
#  82147: 0.0,
#  90150: 0.0,
#  82152: 0.0,
#  82153: 0.09090909090909091,
#  82154: 0.07692307692307693,
#  82155: 0.0,
#  90348: 0.16666666666666666,
#  82157: 0.0,
#  90351: 0.08333333333333333,
#  82162: 0.0,
#  82163: 0.125,
#  91518: 0.0,
#  90359: 0.3,
#  90360: 0.0,
#  90361: 0.15384615384615385,
#  90362: 0.2,
#  82171: 0.0,
#  90364: 0.0,
#  90366: 0.0,
#  82175: 0.0,
#  82179: 0.0,
#  82180: 0.25,
#  90376: 0.0,
#  90377: 0.25,
#  82187: 0.17647058823529413,
#  82188: 0.0,
#  82189: 0.0,
#  90157: 0.2857142857142857,
#  82196: 0.16666666666666666,
#  82197: 0.23076923076923078,
#  82198: 0.06666666666666667,
#  80601: 0.08,
#  82204: 0.0,
#  82205: 0.2,
#  82208: 0.09090909090909091,
#  90401: 0.07692307692307693,
#  82212: 0.25,
#  82213: 0.14285714285714285,
#  82214: 0.0,
#  82219: 0.0,
#  90413: 0.0,
#  82223: 0.0,
#  90416: 0.1,
#  90417: 0.2857142857142857,
#  82228: 0.25,
#  82229: 0.1111111111111111,
#  91529: 0.0,
#  90424: 0.0,
#  82233: 0.14285714285714285,
#  82234: 0.0,
#  82236: 0.06666666666666667,
#  90429: 0.2,
#  82238: 0.08695652173913043,
#  90432: 0.037037037037037035,
#  82243: 0.25,
#  82250: 0.25,
#  90447: 0.2,
#  90449: 0.06666666666666667,
#  82258: 0.13043478260869565,
#  90452: 0.1,
#  90454: 0.25,
#  90456: 0.25,
#  90457: 0.2,
#  90459: 0.03571428571428571,
#  90461: 0.0,
#  82270: 0.14285714285714285,
#  90464: 0.125,
#  82273: 0.2,
#  90467: 0.16666666666666666,
#  82276: 0.0,
#  90469: 0.0,
#  82280: 0.125,
#  82281: 0.14285714285714285,
#  90475: 0.17647058823529413,
#  91538: 0.0,
#  90478: 0.0,
#  82289: 0.09090909090909091,
#  90482: 0.05,
#  90483: 0.0,
#  90485: 0.18181818181818182,
#  82299: 0.2,
#  90492: 0.0,
#  80918: 0.2727272727272727,
#  90494: 0.25,
#  82306: 0.0,
#  82307: 0.25,
#  90501: 0.15384615384615385,
#  90503: 0.16666666666666666,
#  82312: 0.23076923076923078,
#  82314: 0.16666666666666666,
#  90508: 0.14285714285714285,
#  90510: 0.25,
#  82319: 0.0,
#  90514: 0.18181818181818182,
#  90516: 0.15384615384615385,
#  80622: 0.0,
#  90518: 0.0,
#  82327: 0.0,
#  90520: 0.0,
#  82330: 0.06666666666666667,
#  90523: 0.2,
#  90525: 0.0,
#  90526: 0.11764705882352941,
#  90181: 0.15384615384615385,
#  90528: 0.0,
#  80624: 0.4,
#  82340: 0.0,
#  90533: 0.2857142857142857,
#  90534: 0.21428571428571427,
#  90535: 0.0,
#  82344: 0.17647058823529413,
#  82345: 0.1111111111111111,
#  90539: 0.05357142857142857,
#  90543: 0.25,
#  90544: 0.1875,
#  82353: 0.0,
#  82354: 0.09090909090909091,
#  82355: 0.1,
#  82357: 0.14285714285714285,
#  90551: 0.3333333333333333,
#  90552: 0.18181818181818182,
#  82363: 0.2,
#  90556: 0.0,
#  82365: 0.06666666666666667,
#  82366: 0.0,
#  88821: 0.043478260869565216,
#  82368: 0.0,
#  82369: 0.08571428571428572,
#  90562: 0.0,
#  90563: 0.0,
#  90565: 0.2,
#  82375: 0.13333333333333333,
#  82376: 0.25,
#  82377: 0.25,
#  82378: 0.0,
#  82379: 0.11538461538461539,
#  82381: 0.14285714285714285,
#  82382: 0.0,
#  90575: 0.08695652173913043,
#  90576: 0.2,
#  90579: 0.2222222222222222,
#  90580: 0.0,
#  82390: 0.0,
#  90583: 0.0,
#  82393: 0.0,
#  90586: 0.16666666666666666,
#  90587: 0.047619047619047616,
#  90588: 0.1111111111111111,
#  82397: 0.2222222222222222,
#  82399: 0.0,
#  81305: 0.0,
#  90192: 0.09523809523809523,
#  82402: 0.25,
#  82403: 0.0,
#  90596: 0.0,
#  82405: 0.25,
#  90307: 0.15384615384615385,
#  82408: 0.1111111111111111,
#  90601: 0.06451612903225806,
#  90602: 0.0,
#  82411: 0.0,
#  82412: 0.08108108108108109,
#  82414: 0.125,
#  82417: 0.125,
#  90610: 0.11764705882352941,
#  82422: 0.14285714285714285,
#  90615: 0.2222222222222222,
#  82425: 0.0,
#  82426: 0.07692307692307693,
#  90622: 0.0,
#  82432: 0.047619047619047616,
#  90625: 0.14285714285714285,
#  82436: 0.0,
#  82438: 0.2222222222222222,
#  82439: 0.23076923076923078,
#  82440: 0.07692307692307693,
#  90634: 0.2857142857142857,
#  82443: 0.17647058823529413,
#  90636: 0.07692307692307693,
#  82446: 0.0,
#  90639: 0.21428571428571427,
#  82448: 0.18181818181818182,
#  90642: 0.25,
#  90643: 0.3333333333333333,
#  82452: 0.3333333333333333,
#  82454: 0.0,
#  82455: 0.0,
#  82458: 0.0,
#  82459: 0.375,
#  82460: 0.2,
#  82010: 0.3333333333333333,
#  82462: 0.1,
#  90655: 0.0,
#  82470: 0.25,
#  82471: 0.1,
#  82472: 0.2857142857142857,
#  82473: 0.14285714285714285,
#  82474: 0.2222222222222222,
#  82475: 0.2,
#  82477: 0.0,
#  82479: 0.0625,
#  90672: 0.125,
#  82481: 0.0,
#  82482: 0.2,
#  82483: 0.15384615384615385,
#  90676: 0.0,
#  80649: 0.0,
#  82488: 0.0,
#  82490: 0.25,
#  82492: 0.0,
#  82493: 0.07142857142857142,
#  90686: 0.25,
#  90688: 0.3333333333333333,
#  82497: 0.16666666666666666,
#  82498: 0.25,
#  82500: 0.0,
#  90693: 0.16666666666666666,
#  82502: 0.1111111111111111,
#  82503: 0.2857142857142857,
#  80652: 0.14285714285714285,
#  82506: 0.2857142857142857,
#  82508: 0.15,
#  82509: 0.0,
#  82511: 0.1111111111111111,
#  90704: 0.0,
#  91576: 0.10526315789473684,
#  82514: 0.2857142857142857,
#  82517: 0.2,
#  82518: 0.16666666666666666,
#  82519: 0.0,
#  90715: 0.0,
#  91578: 0.0,
#  82526: 0.0,
#  82529: 0.07692307692307693,
#  82530: 0.0,
#  90723: 0.0,
#  82532: 0.16666666666666666,
#  82534: 0.3333333333333333,
#  90729: 0.25,
#  82539: 0.25,
#  82540: 0.13333333333333333,
#  82542: 0.2857142857142857,
#  82543: 0.4,
#  82544: 0.2,
#  82548: 0.06666666666666667,
#  82549: 0.05555555555555555,
#  82550: 0.0,
#  90743: 0.0,
#  90745: 0.25,
#  82554: 0.0,
#  82557: 0.2727272727272727,
#  82560: 0.09375,
#  82563: 0.0,
#  82565: 0.125,
#  82567: 0.0,
#  82568: 0.0,
#  82571: 0.0,
#  90765: 0.18181818181818182,
#  82574: 0.1,
#  90769: 0.0,
#  90770: 0.0,
#  82579: 0.25,
#  90776: 0.0,
#  82585: 0.07142857142857142,
#  90778: 0.0,
#  90779: 0.16666666666666666,
#  82592: 0.0,
#  90224: 0.0,
#  90787: 0.4,
#  82597: 0.25,
#  82598: 0.25,
#  90225: 0.5,
#  90792: 0.0,
#  82601: 0.2,
#  82602: 0.3333333333333333,
#  82603: 0.25,
#  82606: 0.09090909090909091,
#  82608: 0.15384615384615385,
#  82609: 0.05555555555555555,
#  82611: 0.2857142857142857,
#  82612: 0.0,
#  90805: 0.2222222222222222,
#  90806: 0.07692307692307693,
#  82615: 0.1,
#  90228: 0.14285714285714285,
#  82618: 0.0,
#  80671: 0.16666666666666666,
#  82621: 0.0,
#  90817: 0.2,
#  82626: 0.0,
#  90819: 0.25,
#  82628: 0.2,
#  90821: 0.0,
#  90823: 0.0,
#  82633: 0.0,
#  82635: 0.25,
#  90828: 0.0,
#  90829: 0.1,
#  90830: 0.14285714285714285,
#  82639: 0.14285714285714285,
#  82640: 0.125,
#  82641: 0.2,
#  82643: 0.2222222222222222,
#  90837: 0.2,
#  90838: 0.25,
#  90839: 0.25,
#  90840: 0.18181818181818182,
#  82649: 0.16666666666666666,
#  90844: 0.09090909090909091,
#  90845: 0.1111111111111111,
#  90848: 0.16666666666666666,
#  82658: 0.13333333333333333,
#  82659: 0.0,
#  90855: 0.18181818181818182,
#  82664: 0.18181818181818182,
#  90236: 0.07692307692307693,
#  82667: 0.0,
#  90860: 0.42857142857142855,
#  82669: 0.0,
#  82670: 0.0,
#  90863: 0.0,
#  82674: 0.375,
#  90867: 0.0,
#  82677: 0.0,
#  90871: 0.2,
#  82680: 0.2,
#  90873: 0.21428571428571427,
#  82683: 0.0,
#  82684: 0.0,
#  90880: 0.17647058823529413,
#  82689: 0.0,
#  82690: 0.2222222222222222,
#  82691: 0.16666666666666666,
#  82692: 0.0,
#  82695: 0.0,
#  82697: 0.0,
#  82698: 0.2,
#  90891: 0.3333333333333333,
#  82700: 0.0,
#  82701: 0.0,
#  82702: 0.125,
#  80685: 0.09523809523809523,
#  82705: 0.0,
#  82707: 0.21428571428571427,
#  82709: 0.0,
#  90904: 0.125,
#  82715: 0.2222222222222222,
#  82716: 0.4,
#  82718: 0.0,
#  90913: 0.25,
#  90914: 0.2,
#  82723: 0.18181818181818182,
#  82724: 0.16666666666666666,
#  80689: 0.16666666666666666,
#  90920: 0.09090909090909091,
#  82729: 0.125,
#  82730: 0.2,
#  90923: 0.0,
#  82733: 0.11764705882352941,
#  82736: 0.0,
#  90930: 0.4,
#  82740: 0.0,
#  82742: 0.2222222222222222,
#  82743: 0.0,
#  82744: 0.0,
#  90937: 0.2857142857142857,
#  82747: 0.0,
#  82751: 0.2,
#  90945: 0.25,
#  90946: 0.13043478260869565,
#  82755: 0.2,
#  82756: 0.25,
#  82761: 0.14285714285714285,
#  82763: 0.1111111111111111,
#  82764: 0.2,
#  82765: 0.375,
#  82766: 0.14285714285714285,
#  90961: 0.0,
#  90964: 0.0,
#  82776: 0.0,
#  82778: 0.0,
#  90973: 0.09523809523809523,
#  90976: 0.18181818181818182,
#  82785: 0.05,
#  90978: 0.08695652173913043,
#  90979: 0.09090909090909091,
#  82788: 0.1,
#  82789: 0.0,
#  82791: 0.0,
#  90984: 0.21428571428571427,
#  90985: 0.07142857142857142,
#  82794: 0.1,
#  90987: 0.2,
#  90258: 0.0,
#  82798: 0.25,
#  91624: 0.10526315789473684,
#  82802: 0.15,
#  82803: 0.125,
#  90999: 0.09090909090909091,
#  82810: 0.25,
#  84799: 0.10526315789473684,
#  82813: 0.08333333333333333,
#  91007: 0.3333333333333333,
#  82818: 0.125,
#  91011: 0.15,
#  82821: 0.0,
#  91014: 0.05555555555555555,
#  82824: 0.1,
#  82825: 0.2,
#  82827: 0.0,
#  91020: 0.041666666666666664,
#  82830: 0.0,
#  91023: 0.1,
#  90264: 0.2,
#  82835: 0.0,
#  91028: 0.25,
#  82837: 0.0,
#  82838: 0.5,
#  91032: 0.18181818181818182,
#  91034: 0.0,
#  91631: 0.125,
#  90266: 0.42857142857142855,
#  82846: 0.1,
#  80709: 0.14285714285714285,
#  91040: 0.07692307692307693,
#  91041: 0.1111111111111111,
#  82853: 0.2,
#  82854: 0.0,
#  82857: 0.0,
#  82858: 0.0,
#  82859: 0.2857142857142857,
#  82860: 0.2857142857142857,
#  91053: 0.0,
#  91054: 0.3333333333333333,
#  90269: 0.25,
#  80765: 0.25,
#  82868: 0.0,
#  82870: 0.2,
#  82873: 0.07142857142857142,
#  82874: 0.0,
#  82875: 0.2857142857142857,
#  82876: 0.1,
#  82877: 0.0,
#  91070: 0.16666666666666666,
#  82880: 0.2,
#  91073: 0.25,
#  82883: 0.25,
#  91076: 0.0,
#  82886: 0.25,
#  82887: 0.2727272727272727,
#  91083: 0.2,
#  82893: 0.2222222222222222,
#  82894: 0.0,
#  84813: 0.045454545454545456,
#  91090: 0.25,
#  82899: 0.07692307692307693,
#  82900: 0.1111111111111111,
#  80718: 0.2857142857142857,
#  91094: 0.25,
#  91096: 0.25,
#  91099: 0.2,
#  82910: 0.1,
#  91103: 0.0,
#  82913: 0.07142857142857142,
#  82915: 0.0,
#  82916: 0.09090909090909091,
#  90278: 0.16666666666666666,
#  82920: 0.25,
#  82922: 0.13333333333333333,
#  82923: 0.1111111111111111,
#  82924: 0.0,
#  82925: 0.2,
#  82931: 0.1111111111111111,
#  82932: 0.0,
#  91125: 0.09090909090909091,
#  90281: 0.08333333333333333,
#  82937: 0.0,
#  91130: 0.0,
#  82940: 0.0,
#  91133: 0.0,
#  91135: 0.14285714285714285,
#  82945: 0.0,
#  82947: 0.16666666666666666,
#  82949: 0.0,
#  82950: 0.0,
#  91143: 0.0,
#  82953: 0.125,
#  91146: 0.0,
#  80727: 0.0,
#  82956: 0.3333333333333333,
#  91149: 0.0,
#  91151: 0.08333333333333333,
#  82961: 0.0,
#  82963: 0.3333333333333333,
#  82967: 0.08333333333333333,
#  91160: 0.25,
#  82969: 0.16666666666666666,
#  82970: 0.6,
#  82971: 0.047619047619047616,
#  91164: 0.0,
#  91165: 0.0,
#  82974: 0.0,
#  91168: 0.16666666666666666,
#  91170: 0.2,
#  82980: 0.15384615384615385,
#  82981: 0.08108108108108109,
#  91174: 0.125,
#  82983: 0.2222222222222222,
#  82985: 0.25,
#  91178: 0.0,
#  91179: 0.2857142857142857,
#  82989: 0.0,
#  82992: 0.1111111111111111,
#  82995: 0.3333333333333333,
#  82996: 0.25,
#  82997: 0.2222222222222222,
#  91190: 0.09090909090909091,
#  82999: 0.21428571428571427,
#  83000: 0.08333333333333333,
#  91195: 0.08108108108108109,
#  80234: 0.1,
#  83007: 0.0,
#  80736: 0.0,
#  83011: 0.2,
#  83012: 0.14285714285714285,
#  83013: 0.0,
#  83014: 0.0,
#  83016: 0.0,
#  83017: 0.0,
#  91211: 0.0,
#  83022: 0.09523809523809523,
#  83023: 0.0,
#  83024: 0.14285714285714285,
#  91217: 0.16666666666666666,
#  83026: 0.0,
#  83027: 0.25,
#  83029: 0.14285714285714285,
#  83030: 0.0,
#  91224: 0.0,
#  83034: 0.0,
#  91230: 0.14285714285714285,
#  83039: 0.08333333333333333,
#  91234: 0.15789473684210525,
#  80742: 0.0,
#  91239: 0.0,
#  91241: 0.25,
#  91243: 0.23076923076923078,
#  83052: 0.1875,
#  83053: 0.0,
#  83054: 0.08823529411764706,
#  90301: 0.2857142857142857,
#  83056: 0.0,
#  91249: 0.0,
#  83058: 0.1111111111111111,
#  83060: 0.07894736842105263,
#  83061: 0.4,
#  83064: 0.25,
#  83065: 0.2,
#  91258: 0.0,
#  91259: 0.2857142857142857,
#  83069: 0.18181818181818182,
#  83070: 0.11764705882352941,
#  91263: 0.16666666666666666,
#  83072: 0.09090909090909091,
#  91265: 0.0,
#  83074: 0.0,
#  91268: 0.08571428571428572,
#  91270: 0.0,
#  80748: 0.16666666666666666,
#  91274: 0.0,
#  91278: 0.25,
#  83087: 0.2,
#  91280: 0.0,
#  83089: 0.18181818181818182,
#  83091: 0.14285714285714285,
#  91285: 0.1111111111111111,
#  83094: 0.5,
#  91287: 0.0,
#  91288: 0.0,
#  83097: 0.14285714285714285,
#  83098: 0.1111111111111111,
#  83099: 0.25,
#  83100: 0.18181818181818182,
#  91293: 0.17647058823529413,
#  83102: 0.16666666666666666,
#  83104: 0.0,
#  91297: 0.0,
#  91299: 0.0,
#  91304: 0.10526315789473684,
#  83113: 0.0,
#  83115: 0.0,
#  83119: 0.0,
#  91312: 0.0,
#  90312: 0.0,
#  83123: 0.2,
#  91316: 0.25,
#  83125: 0.3333333333333333,
#  83126: 0.0,
#  91323: 0.0,
#  91324: 0.05405405405405406,
#  91326: 0.3333333333333333,
#  83135: 0.0,
#  83136: 0.0,
#  91331: 0.1111111111111111,
#  83140: 0.25,
#  83141: 0.0,
#  91334: 0.25,
#  91336: 0.25,
#  83147: 0.14285714285714285,
#  83149: 0.0,
#  91344: 0.16666666666666666,
#  83154: 0.25,
#  91348: 0.14285714285714285,
#  91349: 0.2,
#  91350: 0.3333333333333333,
#  83160: 0.0,
#  83161: 0.0,
#  91356: 0.0,
#  80762: 0.25,
#  83168: 0.2,
#  91361: 0.3333333333333333,
#  91362: 0.6,
#  91363: 0.25,
#  91365: 0.0,
#  83178: 0.0,
#  91372: 0.2,
#  90322: 0.0,
#  83183: 0.0,
#  83185: 0.2222222222222222,
#  91378: 0.07407407407407407,
#  91379: 0.16666666666666666,
#  91381: 0.058823529411764705,
#  83192: 0.2,
#  91385: 0.11538461538461539,
#  91387: 0.2,
#  91690: 0.4,
#  91390: 0.0,
#  91393: 0.16666666666666666,
#  83202: 0.0,
#  91396: 0.25,
#  91397: 0.1,
#  91398: 0.42857142857142855,
#  83209: 0.2,
#  91403: 0.25,
#  83212: 0.0,
#  83213: 0.16666666666666666,
#  83214: 0.21428571428571427,
#  83216: 0.2,
#  83218: 0.0,
#  83219: 0.14285714285714285,
#  83220: 0.125,
#  83221: 0.0,
#  91415: 0.14285714285714285,
#  91416: 0.15384615384615385,
#  80772: 0.5,
#  83228: 0.42857142857142855,
#  91421: 0.2,
#  91422: 0.125,
#  83232: 0.1,
#  91696: 0.0,
#  83234: 0.2,
#  91429: 0.2,
#  91431: 0.25,
#  83241: 0.16666666666666666,
#  91435: 0.25,
#  83246: 0.2,
#  91439: 0.25,
#  91442: 0.25,
#  83251: 0.2,
#  80777: 0.0,
#  91451: 0.25,
#  91452: 0.25,
#  91454: 0.4,
#  91455: 0.0,
#  83264: 0.0,
#  91458: 0.1,
#  91459: 0.125,
#  83268: 0.0,
#  91463: 0.0,
#  83272: 0.3333333333333333,
#  83273: 0.0625,
#  83274: 0.11764705882352941,
#  83276: 0.2222222222222222,
#  91469: 0.14285714285714285,
#  91471: 0.15789473684210525,
#  83280: 0.0,
#  83282: 0.0,
#  91476: 0.2,
#  91478: 0.14285714285714285,
#  83288: 0.2222222222222222,
#  83289: 0.0,
#  83290: 0.2222222222222222,
#  91486: 0.0,
#  80784: 0.0,
#  83300: 0.1875,
#  83301: 0.09090909090909091,
#  91496: 0.25,
#  83306: 0.0,
#  83308: 0.15384615384615385,
#  83309: 0.0,
#  91502: 0.0,
#  91504: 0.0,
#  91505: 0.07692307692307693,
#  91509: 0.2,
#  91512: 0.14285714285714285,
#  91514: 0.125,
#  91515: 0.1,
#  83324: 0.1,
#  83325: 0.5,
#  83326: 0.14285714285714285,
#  83327: 0.125,
#  91712: 0.25,
#  91522: 0.2,
#  83331: 0.13636363636363635,
#  83332: 0.06666666666666667,
#  83333: 0.1111111111111111,
#  91526: 0.0,
#  83335: 0.16666666666666666,
#  83336: 0.16666666666666666,
#  83337: 0.1875,
#  83338: 0.25,
#  83339: 0.2,
#  83340: 0.0,
#  83342: 0.0,
#  83343: 0.125,
#  83344: 0.4,
#  80792: 0.25,
#  83346: 0.16666666666666666,
#  80791: 0.3333333333333333,
#  83349: 0.2,
#  83350: 0.0,
#  91544: 0.14285714285714285,
#  83353: 0.4,
#  83354: 0.0,
#  91547: 0.2,
#  83358: 0.0,
#  83361: 0.1111111111111111,
#  83364: 0.25,
#  91557: 0.11764705882352941,
#  91558: 0.05555555555555555,
#  83369: 0.25,
#  91564: 0.0,
#  83373: 0.2222222222222222,
#  83374: 0.2,
#  83375: 0.0,
#  83376: 0.0,
#  83377: 0.16666666666666666,
#  90355: 0.0,
#  91573: 0.125,
#  91575: 0.0,
#  83384: 0.16666666666666666,
#  83386: 0.0,
#  83388: 0.15789473684210525,
#  83389: 0.1111111111111111,
#  91582: 0.1,
#  91583: 0.14285714285714285,
#  91584: 0.0,
#  80800: 0.0,
#  91723: 0.0,
#  83397: 0.25,
#  83398: 0.3333333333333333,
#  80801: 0.0,
#  83400: 0.08333333333333333,
#  83401: 0.05660377358490566,
#  80520: 0.0,
#  83403: 0.2222222222222222,
#  91598: 0.14285714285714285,
#  91602: 0.0,
#  91603: 0.2,
#  91604: 0.0,
#  83413: 0.3333333333333333,
#  91607: 0.16666666666666666,
#  91608: 0.13333333333333333,
#  83418: 0.0,
#  91727: 0.2,
#  83420: 0.07142857142857142,
#  91615: 0.13333333333333333,
#  83424: 0.0,
#  83425: 0.0,
#  91619: 0.0,
#  83428: 0.06666666666666667,
#  83429: 0.2857142857142857,
#  91622: 0.13333333333333333,
#  91623: 0.0,
#  83432: 0.07142857142857142,
#  83433: 0.1,
#  91626: 0.0,
#  83437: 0.0,
#  83439: 0.07692307692307693,
#  91632: 0.14285714285714285,
#  91731: 0.2,
#  91636: 0.08333333333333333,
#  83448: 0.0,
#  91641: 0.0,
#  91642: 0.0,
#  91643: 0.061224489795918366,
#  91646: 0.1111111111111111,
#  83458: 0.0,
#  83462: 0.0625,
#  91655: 0.14285714285714285,
#  91657: 0.0,
#  83466: 0.0,
#  91661: 0.0,
#  91664: 0.0,
#  91666: 0.1111111111111111,
#  83475: 0.14285714285714285,
#  91737: 0.06976744186046512,
#  91674: 0.2,
#  80815: 0.25,
#  91680: 0.0,
#  91681: 0.0,
#  83492: 0.25,
#  91685: 0.25,
#  83494: 0.0,
#  91687: 0.0,
#  83498: 0.25,
#  91692: 0.25,
#  83504: 0.16666666666666666,
#  91697: 0.10526315789473684,
#  83507: 0.0,
#  91700: 0.25,
#  91701: 0.0,
#  83510: 0.06666666666666667,
#  83511: 0.16666666666666666,
#  83513: 0.16666666666666666,
#  91706: 0.0,
#  90344: 0.0,
#  91710: 0.0,
#  83520: 0.0,
#  83525: 0.23076923076923078,
#  83526: 0.25,
#  83527: 0.1,
#  80797: 0.0,
#  83529: 0.16666666666666666,
#  83531: 0.0,
#  91725: 0.0,
#  83534: 0.0,
#  83535: 0.0,
#  83536: 0.25,
#  83537: 0.25,
#  91730: 0.0,
#  83539: 0.0,
#  83540: 0.0,
#  91734: 0.0,
#  80825: 0.3333333333333333,
#  83545: 0.0,
#  83546: 0.0,
#  83549: 0.0,
#  83550: 0.0,
#  91745: 0.2222222222222222,
#  83554: 0.2222222222222222,
#  83555: 0.4,
#  83556: 0.3333333333333333,
#  83557: 0.047619047619047616,
#  83558: 0.25,
#  83560: 0.058823529411764705,
#  91760: 0.0,
#  91752: 0.2857142857142857,
#  83571: 0.125,
#  83573: 0.0,
#  91768: 0.16666666666666666,
#  91774: 0.0,
#  90389: 0.2,
#  83584: 0.1111111111111111,
#  83585: 0.06666666666666667,
#  83586: 0.16666666666666666,
#  91780: 0.25,
#  83594: 0.2,
#  91787: 0.1111111111111111,
#  ...}

# %%
# ANSWER
similarities = {}
for user_id, brands in brandsfor.iteritems():
    similarities[user_id] = jaccard(given_user, brands)
similarities[81920]
# Out:
# 0.07142857142857142

# %%
K = 5 #number of similar users to look at

# %%
# Now for the top K most similar users, let's aggregate the brands they like.
# I sort by the jaccard similarty so most similar users are first
# I use the sorted method, but because I'm dorting dictionaries
# I specify the "key" as the value of the dictionary
# the key is what the list should sort on
# so the most similar users end up being on top
# ANSWER HEREEEEEE

# %%
# list of K similar users' IDs
most_similar_users = sorted(similarities.items(), key = lambda x: x[1], reverse=True)[:K]
most_similar_users
# Out:
# [(81012, 0.75), (82970, 0.6), (91362, 0.6), (84807, 0.6), (88549, 0.6)]

# %%
# let's see what some of the most similar users likes
brandsfor[most_similar_users[0][0]]
# Out:
# ['Banana Republic', 'Old Navy', 'Target']

# %%
brandsfor[most_similar_users[3][0]]
# Out:
# ['Steve Madden', 'Banana Republic', 'Old Navy', 'Target']

# %%
# Aggregate all brands liked by the K most similar users into a single set
brands_to_recommend = set()
for user in most_similar_users:
    print user[0]
    brands_to_recommend |= set(brandsfor[user[0]])
    # ANSWER HEREEEEEE
    # add to the set of brands_to_recommend
# Out:
# 81012
# 82970
# 91362
# 84807
# 88549

# %%
# Aggregate all brands liked by the K most similar users into a single set
# be sure to not include brands the the given user is already known to like1
brands_to_recommend = []
for user in most_similar_users:
    print user[0]
    for brand in brandsfor[user[0]]:
        if brand not in given_user:
            brands_to_recommend.append(brand)
# Out:
# 81012
# 82970
# 91362
# 84807
# 88549

# %%
brands_to_recommend
# UH OH WE HAVE DUPLICATES. Banana Republic, Old Navy, Target are all repeats.
# let's caculate a "score" of recommendation
# We will define the score as being the number of times
# a brand appears within the first K users
# Out:
# ['Gap', 'Gap', 'Steve Madden', 'Forever 21']

# %%
from collections import Counter
dict(Counter(brands_to_recommend))
# Out:
# {'Forever 21': 1, 'Gap': 2, 'Steve Madden': 1}

# %%
#################################
#### Collaborative Item based ###
#################################

# %%
# '''
# We can also define a similary between items using jaccard similarity.
# We can say that the similarity between two items is the jaccard similarity
# between the sets of people who like the two brands.

# Example: similarity of Gap to Target is:
# '''

# %%
# filter users by liking Gap
gap_lovers = set(user_brands['Gap' == user_brands.Store].ID)
old_navy_lovers = set(user_brands['Old Navy' == user_brands.Store].ID)

# %%
# similarty between Gap and Old Navy
jaccard(gap_lovers, old_navy_lovers)
# Out:
# 0.35437212360289283

# %%
guess_lovers = set(user_brands['Guess' == user_brands.Store].ID)
# similarty between Gap andGuess
jaccard(guess_lovers, gap_lovers)
# Out:
# 0.21257750221434898

# %%
calvin_lovers = set(user_brands['Calvin Klein' == user_brands.Store].ID)
# similarty between Gap and Calvin Klein
jaccard(calvin_lovers, gap_lovers)
# Out:
# 0.2068654019873532

# %%
Target_lovers = set(user_brands['Target' == user_brands.Store].ID)
# similarty between Gap and Calvin Klein
jaccard(Target_lovers, gap_lovers)
# Out:
# 0.3304050756466569
